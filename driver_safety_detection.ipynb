# %%
from google.colab import drive
drive.mount ('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/dataset/dataset.zip -d /content
# Out:
# Archive:  /content/drive/MyDrive/dataset/dataset.zip
#    creating: /content/dataset/
#    creating: /content/dataset/test/
#   inflating: /content/dataset/test/1.jpg
#   inflating: /content/dataset/test/1.txt
#   inflating: /content/dataset/test/10.jpg
#   inflating: /content/dataset/test/10.txt
#   inflating: /content/dataset/test/101.jpg
#   inflating: /content/dataset/test/101.txt
#   inflating: /content/dataset/test/102.jpg
#   inflating: /content/dataset/test/102.txt
#   inflating: /content/dataset/test/103.jpg
#   inflating: /content/dataset/test/103.txt
#   inflating: /content/dataset/test/104.jpg
#   inflating: /content/dataset/test/104.txt
#   inflating: /content/dataset/test/105.jpg
#   inflating: /content/dataset/test/105.txt
#   inflating: /content/dataset/test/106.jpg
#   inflating: /content/dataset/test/106.txt
#   inflating: /content/dataset/test/107.jpg
#   inflating: /content/dataset/test/107.txt
#   inflating: /content/dataset/test/108.jpg
# ...

# %%
# %%writefile data.yaml
# train: /content/dataset/train
#
# val: /content/dataset/test
#
# nc: 5
# names: [active,distraction,fatigue,seatbelt,no_seatbelt]
# Out:
# Writing data.yaml

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 749.1/749.1 kB 9.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 10.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 47.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 65.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 5.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 2.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 5.3 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
model = YOLO('yolov5su.pt')
model.train(data = "/content/data.yaml",epochs=20)
# Out:
# ...
# 100%|██████████| 17.7M/17.7M [00:00<00:00, 117MB/s]
# Ultralytics YOLOv8.1.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
model = YOLO('/content/runs/detect/train2/weights/best.pt')
predictions = model.predict('/content/seat_belt_3.jpg')
